# %%
import andes
from andes.utils import get_case

# %%
system = get_case('local/1_inv_1_load.xlsx')

# calculate power flow

# use constant power model for PQ (we will come back to this later)

ss = andes.load(system)
# Out:
# Synchronverter: redefinition of member <p0>
# Synchronverter: redefinition of member <q0>

# %%
ss.PQ.config.p2p = 1
ss.PQ.config.q2q = 1
ss.PQ.config.p2z = 0
ss.PQ.config.q2z = 0

# %%
ss.PFlow.run()
# Out:
# True

# %%
ss.TDS.config.tf = 1

# %%
ss.TDS.run()
# Out:
# 100%|██████████████████████████████| 100/100 [00:00<00:00, 2086.85%/s]
# True

# %%
ss.TDS.plotter.plot(ss.Synchronverter.omega)
# Out:
# (<Figure size 900x600 with 1 Axes>, <AxesSubplot:xlabel='Time [s]'>)

# %%
#ss.PQ.Ppf.v

# %%
#ss.PQ.set(src='Ppf', idx='PQ_0', attr='v', value=0.01)

# %%
#ss.PQ.Ppf.v

# %%
ss.Synchronverter.paux0.v
# Out:
# array([0.])

# %%
ss.Synchronverter.paux0.v[0] = 5

# %%
ss.Synchronverter.paux0.v
# Out:
# array([5.])

# %%
ss.TDS.config.tf = 20

# %%
ss.TDS.run()
# Out:
# 100%|█████████████████████████████| 100.0/100 [00:00<00:00, 264.62%/s]
# True

# %%
#ss.TDS.plotter.plot(ss.PQ.Ppf)

# %%
ss.TDS.plotter.plot(ss.Synchronverter.theta_s)
ss.TDS.plotter.plot(ss.Synchronverter.a)
ss.Synchronverter.bsh.v
# Out:
# array([-2.49999944e-08])

# %%
ss.Synchronverter.gsh.v
# Out:
# array([1.18749973e-11])

# %%
ss.Synchronverter.es.v
# Out:
# array([1.])

# %%
ss.TDS.plotter.plot(ss.Synchronverter.a)
# Out:
# (<Figure size 900x600 with 1 Axes>, <AxesSubplot:xlabel='Time [s]'>)
